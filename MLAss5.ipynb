# %%
#a) Implement the Find-S algorithm on the data sets provided to you to induce hypotheses from training data

# ---------------------------
# Find-S Algorithm in Python
# ---------------------------

import pandas as pd

# Sample dataset (EnjoySport)
data = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Cold', 'Change', 'No'],
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Cold', 'Change', 'Yes']
]

# Define column names
columns = ['Sky', 'AirTemp', 'Humidity', 'Wind', 'Water', 'Forecast', 'EnjoySport']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# ---------------------------
# Find-S Algorithm Function
# ---------------------------

def find_s(training_df, target_col='EnjoySport', positive_label='Yes'):
    attributes = training_df.columns[:-1]  # all columns except target
    hypothesis = ['0'] * len(attributes)   # most specific hypothesis (initial)
    
    # Iterate through each training example
    for i in range(len(training_df)):
        if training_df.iloc[i][target_col] == positive_label:  # positive example
            for j in range(len(attributes)):
                if hypothesis[j] == '0':  # if attribute not yet set
                    hypothesis[j] = training_df.iloc[i][j]
                elif hypothesis[j] != training_df.iloc[i][j]:
                    hypothesis[j] = '?'  # generalize if values differ
    return hypothesis

# ---------------------------
# Run Find-S Algorithm
# ---------------------------

final_hypothesis = find_s(df)
print("Final Hypothesis (Find-S):")
print("<", ', '.join(final_hypothesis), ">")
# Out:
# Final Hypothesis (Find-S):
# < Sunny, Warm, ?, Strong, ?, ? >
# C:\Users\malij\AppData\Local\Temp\ipykernel_20776\2276041008.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hypothesis[j] = training_df.iloc[i][j]
# C:\Users\malij\AppData\Local\Temp\ipykernel_20776\2276041008.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif hypothesis[j] != training_df.iloc[i][j]:

# %%
#b) Implement the Candidate Elimination (aka List-Then-Eliminate) algorithm on the data sets provided to you to list of all possible hypotheses and eliminating the ones that do not fit the training examples.

# -------------------------------
# Candidate Elimination Algorithm
# -------------------------------

import pandas as pd

# Sample training dataset (EnjoySport)
data = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Cold', 'Change', 'Yes']
]

# Define columns
columns = ['Sky', 'AirTemp', 'Humidity', 'Wind', 'Water', 'Forecast', 'EnjoySport']
df = pd.DataFrame(data, columns=columns)

# -------------------------------
# Candidate Elimination Function
# -------------------------------

def candidate_elimination(training_data):
    # Get attributes and target
    attributes = training_data.columns[:-1]
    target = training_data.columns[-1]
    
    # Initialize S (Specific boundary) with first positive example
    S = list(training_data[training_data[target] == 'Yes'].iloc[0, :-1])
    
    # Initialize G (General boundary) with most general hypothesis
    G = [['?' for _ in range(len(S))]]
    
    # Iterate through training examples
    for i, row in training_data.iterrows():
        example, label = row[:-1], row[-1]
        
        if label == 'Yes':  # Positive example
            # Remove inconsistent hypotheses from G
            G = [g for g in G if consistent(g, example)]
            
            # Update S: make it more general if needed
            for j in range(len(S)):
                if S[j] != example[j]:
                    S[j] = '?'
                    
        elif label == 'No':  # Negative example
            # For each hypothesis in G
            new_G = []
            for g in G:
                # If g is consistent with negative example, specialize it
                if consistent(g, example):
                    new_hypotheses = specialize(g, example, attributes, S)
                    new_G.extend(new_hypotheses)
                else:
                    new_G.append(g)
            G = remove_more_general(new_G)
    
    return S, G


# -------------------------------
# Helper Functions
# -------------------------------

def consistent(hypothesis, example):
    """Check if hypothesis is consistent with example"""
    return all(h == '?' or h == e for h, e in zip(hypothesis, example))

def specialize(hypothesis, example, attributes, S):
    """Generate specializations of a hypothesis that exclude the example"""
    specializations = []
    for i in range(len(hypothesis)):
        if hypothesis[i] == '?':
            for val in training_values(attributes[i]):
                if val != example[i] and (S[i] == '?' or val == S[i]):
                    new_h = hypothesis.copy()
                    new_h[i] = val
                    specializations.append(new_h)
    return specializations

def training_values(attr):
    """Return possible values for a given attribute"""
    values = {
        'Sky': ['Sunny', 'Rainy'],
        'AirTemp': ['Warm', 'Cold'],
        'Humidity': ['High', 'Normal'],
        'Wind': ['Strong', 'Weak'],
        'Water': ['Warm', 'Cold'],
        'Forecast': ['Same', 'Change']
    }
    return values[attr]

def remove_more_general(hypotheses):
    """Remove hypotheses that are more general than others"""
    final_list = []
    for h in hypotheses:
        if not any(more_general(h2, h) for h2 in hypotheses if h != h2):
            final_list.append(h)
    return final_list

def more_general(h1, h2):
    """Check if h1 is more general than h2"""
    return all(h1[i] == '?' or h1[i] == h2[i] for i in range(len(h1)))


# -------------------------------
# Run the Algorithm
# -------------------------------

S, G = candidate_elimination(df)

print("\nFinal Specific Hypothesis (S):")
print("<", ', '.join(S), ">")

print("\nFinal General Hypotheses (G):")
for g in G:
    print("<", ', '.join(g), ">")
# Out:
# Final Specific Hypothesis (S):
# < Sunny, Warm, ?, Strong, ?, ? >
#
# Final General Hypotheses (G):
# < Sunny, ?, ?, ?, ?, ? >
# < ?, Warm, ?, ?, ?, ? >
# C:\Users\malij\AppData\Local\Temp\ipykernel_20776\2697241568.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   example, label = row[:-1], row[-1]
# C:\Users\malij\AppData\Local\Temp\ipykernel_20776\2697241568.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if S[j] != example[j]:
# C:\Users\malij\AppData\Local\Temp\ipykernel_20776\2697241568.py:78: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if val != example[i] and (S[i] == '?' or val == S[i]):

# %%
import pandas as pd

# Load dataset

data = pd.read_csv("/diabetes.csv")

X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values


threshold = y.mean()
y_positive = (y > threshold).astype(int)

for i in range(len(y_positive)):
    if y_positive[i] == 1:
        hypothesis = X[i].tolist()
        print(f"Initial hypothesis (from first positive example): {hypothesis}")
        break

# Find-S algorithm with step-by-step output
for i in range(len(y_positive)):
    if y_positive[i] == 1:
        for j in range(len(hypothesis)):
            if hypothesis[j] != X[i][j]:
                hypothesis[j] = '?'
        print(f"Hypothesis after processing example {i+1}: {hypothesis}")

print("\nFinal hypothesis:", hypothesis)
# Out:
# Initial hypothesis (from first positive example): [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0]
# Hypothesis after processing example 1: [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0]
# Hypothesis after processing example 3: ['?', '?', '?', '?', 0.0, '?', '?', '?']
# Hypothesis after processing example 5: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 7: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 9: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 10: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 12: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 14: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 15: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 16: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 17: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 18: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 20: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 23: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 24: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 25: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 26: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 27: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 32: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 38: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 39: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 40: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 44: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 46: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 49: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 54: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 57: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 62: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 65: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 67: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 71: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 73: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 79: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 85: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 89: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 94: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 100: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 101: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 110: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 111: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 112: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 115: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 116: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 117: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 121: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 125: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 126: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 129: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 130: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 131: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 132: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 133: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 144: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 153: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 155: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 156: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 160: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 165: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 166: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 171: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 172: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 176: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 178: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 180: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 186: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 187: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 188: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 189: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 190: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 193: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 194: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 196: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 198: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 199: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 200: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 207: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 208: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 210: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 214: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 215: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 216: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 217: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 219: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 220: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 221: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 222: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 228: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 231: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 232: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 236: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 237: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 238: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 239: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 243: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 244: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 246: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 255: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 256: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 260: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 262: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 265: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 267: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 270: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 271: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 277: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 281: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 284: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 285: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 288: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 292: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 293: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 294: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 297: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 299: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 301: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 302: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 304: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 307: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 309: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 310: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 313: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 315: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 318: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 320: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 322: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 323: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 324: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 327: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 329: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 333: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 338: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 339: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 340: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 350: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 356: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 357: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 358: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 360: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 361: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 364: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 367: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 370: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 371: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 376: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 379: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 387: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 388: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 389: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 392: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 395: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 398: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 400: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 401: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 403: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 405: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 407: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 409: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 410: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 415: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 416: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 418: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 420: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 425: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 426: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 428: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 430: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 436: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 441: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 444: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 445: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 446: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 449: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 452: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 456: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 459: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 469: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 477: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 481: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 485: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 486: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 494: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 499: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 503: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 507: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 511: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 516: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 517: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 524: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 536: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 540: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 541: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 542: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 543: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 546: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 547: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 561: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 562: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 570: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 578: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 580: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 581: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 585: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 587: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 589: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 591: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 593: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 596: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 599: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 604: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 605: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 607: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 612: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 613: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 615: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 619: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 620: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 631: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 636: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 639: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 643: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 647: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 648: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 649: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 656: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 660: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 662: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 663: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 664: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 665: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 667: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 668: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 676: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 677: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 679: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 682: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 684: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 690: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 692: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 694: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 696: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 697: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 702: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 703: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 707: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 709: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 710: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 713: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 716: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 717: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 720: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 723: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 731: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 732: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 733: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 740: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 741: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 744: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 747: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 749: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 750: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 751: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 754: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 755: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 756: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 758: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 760: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 762: ['?', '?', '?', '?', '?', '?', '?', '?']
# Hypothesis after processing example 767: ['?', '?', '?', '?', '?', '?', '?', '?']
#
# Final hypothesis: ['?', '?', '?', '?', '?', '?', '?', '?']
